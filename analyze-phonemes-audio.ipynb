# %%
import scipy

# %%
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile

sample_rate, samples = wavfile.read('Audio/Voiceless_bilabial_plosive.wav')
frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)
print(sample_rate)

plt.pcolormesh(times, frequencies, spectrogram)
plt.imshow(spectrogram)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
# Out:
# 44100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-6001c2fab3d2> in <module>
#       7 print(sample_rate)
#       8
# ----> 9 plt.pcolormesh(times, frequencies, spectrogram)
#      10 plt.imshow(spectrogram)
#      11 plt.ylabel('Frequency [Hz]')
#
# ~/code/shakespeare/shakespeare-env/lib/python3.5/site-packages/matplotlib/pyplot.py in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2773         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2774         vmax=vmax, shading=shading, antialiased=antialiased,
# -> 2775         **({"data": data} if data is not None else {}), **kwargs)
#    2776     sci(__ret)
#    2777     return __ret
#
# ~/code/shakespeare/shakespeare-env/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/code/shakespeare/shakespeare-env/lib/python3.5/site-packages/matplotlib/axes/_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    5980         allmatch = (shading == 'gouraud')
#    5981
# -> 5982         X, Y, C = self._pcolorargs('pcolormesh', *args, allmatch=allmatch)
#    5983         Ny, Nx = X.shape
#    5984         X = X.ravel()
#
# ~/code/shakespeare/shakespeare-env/lib/python3.5/site-packages/matplotlib/axes/_axes.py in _pcolorargs(funcname, allmatch, *args)
#    5547                 if isinstance(Y, np.ma.core.MaskedArray):
#    5548                     Y = Y.data
# -> 5549             numRows, numCols = C.shape
#    5550         else:
#    5551             raise TypeError(
#
# ValueError: too many values to unpack (expected 2)

# %%
import os
import wave

import pylab
def graph_spectrogram(wav_file):
    sound_info, frame_rate = get_wav_info(wav_file)
    pylab.figure(num=None, figsize=(19, 12))
    pylab.subplot(111)
    pylab.title('spectrogram of %r' % wav_file)
    pylab.specgram(sound_info, Fs=frame_rate)
    pylab.savefig('spectrogram.png')
def get_wav_info(wav_file):
    wav = wave.open(wav_file, 'r')
    frames = wav.readframes(-1)
    sound_info = pylab.fromstring(frames, 'int16')
    frame_rate = wav.getframerate()
    wav.close()
    return sound_info, frame_rate

graph_spectrogram('Audio/Voiceless_bilabial_plosive.wav')
# Out:
# /Users/timholdsworth/code/shakespeare/shakespeare-env/lib/python3.5/site-packages/ipykernel_launcher.py:15: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   from ipykernel import kernelapp as app

# %%
graph_spectrogram('Audio/Bilabial_nasal.wav')
# Out:
# /Users/timholdsworth/code/shakespeare/shakespeare-env/lib/python3.5/site-packages/ipykernel_launcher.py:15: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   from ipykernel import kernelapp as app
